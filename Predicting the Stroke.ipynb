# %%
import pandas as pd
df = pd.read_csv('newData.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married work_type  \
# 0  31112    Male  80.0             0              1          Yes   Private
# 1  53882    Male  74.0             1              1          Yes   Private
# 2  10434  Female  69.0             0              0           No   Private
# 3  27419  Female  59.0             0              0          Yes   Private
# 4  60491  Female  78.0             0              0          Yes   Private
#
#   Residence_type  avg_glucose_level    bmi smoking_status  stroke
# 0          Rural             105.92  32.50   never smoked       1
# 1          Rural              70.09  27.40   never smoked       1
# 2          Urban              94.39  22.80   never smoked       1
# 3          Rural              76.15  28.89        Unknown       1
# 4          Urban              58.57  24.20        Unknown       1

# %%
inputs = df.drop(['stroke','id'],axis='columns')
tareget = df['stroke']

# %%
inputs
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  80.0             0              1          Yes        Private
# 1       Male  74.0             1              1          Yes        Private
# 2     Female  69.0             0              0           No        Private
# 3     Female  59.0             0              0          Yes        Private
# 4     Female  78.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4343  Female  13.0             0              0           No       children
# 4344  Female  80.0             1              0          Yes        Private
# 4345  Female  81.0             0              0          Yes  Self-employed
# 4346  Female  35.0             0              0          Yes  Self-employed
# 4347  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_gender = LabelEncoder()
le_hypertension = LabelEncoder()
le_heart_disease =  LabelEncoder()
le_ever_married = LabelEncoder()
le_work_type= LabelEncoder()
le_Residence_type = LabelEncoder()
le_smoking_status =  LabelEncoder()

# %%
inputs['gender_n'] = le_gender.fit_transform(inputs['gender'])
inputs['age_n'] = inputs['age']
inputs['hypertension_n'] = le_hypertension.fit_transform(inputs['hypertension'])
inputs['heart_disease_n'] = le_heart_disease.fit_transform(inputs['heart_disease'])
inputs['ever_married_n'] = le_ever_married.fit_transform(inputs['ever_married'])
inputs['work_type_n'] = le_work_type.fit_transform(inputs['work_type'])
inputs['Residence_type_n'] = le_Residence_type.fit_transform(inputs['Residence_type'])
inputs['avg_glucose_level_n'] = inputs['avg_glucose_level']
inputs['bmi_n'] = inputs['bmi']
inputs['smoking_status_n'] = le_smoking_status.fit_transform(inputs['smoking_status'])
inputs.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married work_type  \
# 0    Male  80.0             0              1          Yes   Private
# 1    Male  74.0             1              1          Yes   Private
# 2  Female  69.0             0              0           No   Private
# 3  Female  59.0             0              0          Yes   Private
# 4  Female  78.0             0              0          Yes   Private
#
#   Residence_type  avg_glucose_level    bmi smoking_status  gender_n  age_n  \
# 0          Rural             105.92  32.50   never smoked         1   80.0
# 1          Rural              70.09  27.40   never smoked         1   74.0
# 2          Urban              94.39  22.80   never smoked         0   69.0
# 3          Rural              76.15  28.89        Unknown         0   59.0
# 4          Urban              58.57  24.20        Unknown         0   78.0
#
#    hypertension_n  heart_disease_n  ever_married_n  work_type_n  \
# ...

# %%
inputs_n = inputs.drop(['gender','hypertension','Residence_type','heart_disease','ever_married','work_type','smoking_status','bmi','avg_glucose_level','age'],axis='columns')
inputs_n
# Out:
#       gender_n  age_n  hypertension_n  heart_disease_n  ever_married_n  \
# 0            1   80.0               0                1               1
# 1            1   74.0               1                1               1
# 2            0   69.0               0                0               0
# 3            0   59.0               0                0               1
# 4            0   78.0               0                0               1
# ...        ...    ...             ...              ...             ...
# 4343         0   13.0               0                0               0
# 4344         0   80.0               1                0               1
# 4345         0   81.0               0                0               1
# 4346         0   35.0               0                0               1
# 4347         0   44.0               0                0               1
#
#       work_type_n  Residence_type_n  avg_glucose_level_n  bmi_n  \
# ...

# %%
from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
array = inputs_n.values
X = array[:,0:7]
Y = array[:,8]
testSize = 0.25
kfold = model_selection.KFold(n_splits=20)

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
cv_results = model_selection.cross_val_score(dtc, X, Y, cv=kfold)
msg = "Mean = %f STD= %f" % (cv_results.mean(), cv_results.std())
print(msg)
# Out:
# Mean = nan STD= nan
# /Users/ameedal-tamimi/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/ameedal-tamimi/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/ameedal-tamimi/opt/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 898, in fit
#     super().fit(
#   File "/Users/ameedal-tamimi/opt/anaconda3/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 190, in fit
#     check_classification_targets(y)
#   File "/Users/ameedal-tamimi/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ...
